# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt
import folium
from ipyleaflet import (Map,DrawControl)
import seaborn as sb
import gmaps

# %% [markdown]
# ## Store CSV into DataFrame

# %%
#main: read in csv and print results
csv = "Resources/2019_nCoV_data.csv"
main_df = pd.read_csv(csv)
main_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
#confirmed: read in csv
csv_confirmed = "Resources/time_series_covid_19_confirmed.csv"
confirmed_df = pd.read_csv(csv_confirmed)
confirmed_df
# Out:
#                   Province/State  Country/Region       Lat      Long  1/22/20  \
# 0                          Anhui  Mainland China  31.82571  117.2264        1
# 1                        Beijing  Mainland China  40.18238  116.4142       14
# 2                      Chongqing  Mainland China  30.05718  107.8740        6
# 3                         Fujian  Mainland China  26.07783  117.9895        1
# 4                          Gansu  Mainland China  36.06110  103.8343        0
# ..                           ...             ...       ...       ...      ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380        0
# 72          San Diego County, CA              US  32.71570 -117.1611        0
# 73               San Antonio, TX              US  29.42410  -98.4936        0
# 74                           NaN           Egypt  26.82060   30.8025        0
# 75                           NaN            Iran  32.42790   53.6880        0
#
# ...

# %%
#deaths: read in csv
csv_deaths = "Resources/time_series_covid_19_deaths.csv"
deaths_df = pd.read_csv(csv_deaths)
deaths_df
# Out:
#                   Province/State  Country/Region       Lat      Long  1/22/20  \
# 0                          Anhui  Mainland China  31.82571  117.2264        0
# 1                        Beijing  Mainland China  40.18238  116.4142        0
# 2                      Chongqing  Mainland China  30.05718  107.8740        0
# 3                         Fujian  Mainland China  26.07783  117.9895        0
# 4                          Gansu  Mainland China  36.06110  103.8343        0
# ..                           ...             ...       ...       ...      ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380        0
# 72          San Diego County, CA              US  32.71570 -117.1611        0
# 73               San Antonio, TX              US  29.42410  -98.4936        0
# 74                           NaN           Egypt  26.82060   30.8025        0
# 75                           NaN            Iran  32.42790   53.6880        0
#
# ...

# %%
#recovered: read in csv
csv_recovered = "Resources/time_series_covid_19_recovered.csv"
recovered_df = pd.read_csv(csv_recovered)
recovered_df
# Out:
#                   Province/State  Country/Region       Lat      Long  1/22/20  \
# 0                          Anhui  Mainland China  31.82571  117.2264        0
# 1                        Beijing  Mainland China  40.18238  116.4142        0
# 2                      Chongqing  Mainland China  30.05718  107.8740        0
# 3                         Fujian  Mainland China  26.07783  117.9895        0
# 4                          Gansu  Mainland China  36.06110  103.8343        0
# ..                           ...             ...       ...       ...      ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380        0
# 72          San Diego County, CA              US  32.71570 -117.1611        0
# 73               San Antonio, TX              US  29.42410  -98.4936        0
# 74                           NaN           Egypt  26.82060   30.8025        0
# 75                           NaN            Iran  32.42790   53.6880        0
#
# ...

# %%
#hubei coordinates
# clean_main_df = main_df.loc[(main_df["Country"] == 'China') | (main_df["Country"] == 'Mainland China')]
# clean_main_df
latlng_hubei_df = recovered_df.loc[recovered_df["Province/State"] == 'Hubei']
latlng_hubei_df
# Out:
#    Province/State  Country/Region       Lat      Long  1/22/20  1/23/20  \
# 12          Hubei  Mainland China  30.97564  112.2707       28       28
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  2/11/20  2/12/20  2/13/20  \
# 12       31       32       42       45  ...     2639     2686     3459
#
#     2/14/20  2/15/20  2/16/20  2/17/20  2/18/20  2/19/20  2/20/20
# 12     4774     5623     6639     7862     9128    10337    11788
#
# [1 rows x 34 columns]

# %% [markdown]
# ## Clean DataFrame

# %%
#clean 'main_df'
#df.loc[(df["B"] > 50) & (df["C"] == 900), "A"]
clean_main_df = main_df.loc[(main_df["Country"] == 'China') | (main_df["Country"] == 'Mainland China')]
clean_main_df
# Out:
#        Sno                 Date  Province/State         Country  \
# 0        1  01/22/2020 12:00:00           Anhui           China
# 1        2  01/22/2020 12:00:00         Beijing           China
# 2        3  01/22/2020 12:00:00       Chongqing           China
# 3        4  01/22/2020 12:00:00          Fujian           China
# 4        5  01/22/2020 12:00:00           Gansu           China
# ...    ...                  ...             ...             ...
# 1672  1673  02/17/2020 22:00:00        Xinjiang  Mainland China
# 1673  1674  02/17/2020 22:00:00  Inner Mongolia  Mainland China
# 1674  1675  02/17/2020 22:00:00         Ningxia  Mainland China
# 1681  1682  02/17/2020 22:00:00         Qinghai  Mainland China
# 1708  1709  02/17/2020 22:00:00           Tibet  Mainland China
#
#               Last Update  Confirmed  Deaths  Recovered
# 0     01/22/2020 12:00:00        1.0     0.0        0.0
# 1     01/22/2020 12:00:00       14.0     0.0        0.0
# ...

# %%
main_df['Country'] = main_df['Country'].replace(
    {'Mainland China': 'China',
    'Hong Kong': 'China',
    'Macau': 'China',
    'Taiwan':'China'})

main_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
#clean confirmed_df; only show 'Province/State', 'Country/Region', 'Lat', 'Long'; then make copy with 'copy()'
clean_confirmed_df = confirmed_df[["Province/State", "Country/Region", "Lat", "Long"]].copy()
clean_confirmed_df
# Out:
#                   Province/State  Country/Region       Lat      Long
# 0                          Anhui  Mainland China  31.82571  117.2264
# 1                        Beijing  Mainland China  40.18238  116.4142
# 2                      Chongqing  Mainland China  30.05718  107.8740
# 3                         Fujian  Mainland China  26.07783  117.9895
# 4                          Gansu  Mainland China  36.06110  103.8343
# ..                           ...             ...       ...       ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380
# 72          San Diego County, CA              US  32.71570 -117.1611
# 73               San Antonio, TX              US  29.42410  -98.4936
# 74                           NaN           Egypt  26.82060   30.8025
# 75                           NaN            Iran  32.42790   53.6880
#
# [76 rows x 4 columns]

# %%
#rename Province/State 'NaN' entries with 'Unknown'
# filled_cleaned_confirmed_df = new_confirmed_df.replace(np.NaN, "Unknown", regex=True)
# values = {'Province/State': "Unknown"} 
# # new_confirmed_df.fillna(value=values)

# %%
#clean deaths_df; replace 'Mainland China', to 'China'; 'Hong Kong' to China, "Macau" to China, "Taiwan" to China
deaths_df['Country/Region'] = deaths_df['Country/Region'].replace(
    {'Mainland China': 'China',
    'Hong Kong': 'China',
    'Macau': 'China'})
deaths_df = deaths_df.rename(columns={"2/20/20": "Deaths"})
deaths_df
# Out:
#                   Province/State Country/Region       Lat      Long  Deaths
# 0                          Anhui          China  31.82571  117.2264       6
# 1                        Beijing          China  40.18238  116.4142       4
# 2                      Chongqing          China  30.05718  107.8740       6
# 3                         Fujian          China  26.07783  117.9895       1
# 4                          Gansu          China  36.06110  103.8343       2
# ..                           ...            ...       ...       ...     ...
# 71  Diamond Princess cruise ship         Others  35.44370  139.6380       2
# 72          San Diego County, CA             US  32.71570 -117.1611       0
# 73               San Antonio, TX             US  29.42410  -98.4936       0
# 74                           NaN          Egypt  26.82060   30.8025       0
# 75                           NaN           Iran  32.42790   53.6880       2
#
# [76 rows x 5 columns]

# %%
deaths_df['Province/State'] = deaths_df['Province/State'].replace(
    {'Cruise Ship': 'Diamond Princess cruise ship',
     'Chicago': 'Chicago, IL',
    'California':'Sacramento, CA',
    'San Diego County, CA':'San Diego, CA',
    'Washington': 'Seattle, WA',
    'Illinois': 'Chicago, IL',
     'Ontario': 'Toronto, ON',
     'Victoria':'Victoria, BC',
     'Arizona': 'Tempe, AZ'
    })
deaths_df
# Out:
#                   Province/State Country/Region       Lat      Long  Deaths
# 0                          Anhui          China  31.82571  117.2264       6
# 1                        Beijing          China  40.18238  116.4142       4
# 2                      Chongqing          China  30.05718  107.8740       6
# 3                         Fujian          China  26.07783  117.9895       1
# 4                          Gansu          China  36.06110  103.8343       2
# ..                           ...            ...       ...       ...     ...
# 71  Diamond Princess cruise ship         Others  35.44370  139.6380       2
# 72                 San Diego, CA             US  32.71570 -117.1611       0
# 73               San Antonio, TX             US  29.42410  -98.4936       0
# 74                           NaN          Egypt  26.82060   30.8025       0
# 75                           NaN           Iran  32.42790   53.6880       2
#
# [76 rows x 5 columns]

# %%
deaths_df.to_csv("output/cleaned_deaths.csv")

# %%
deaths_all = deaths_df.groupby('Country/Region')['Deaths'].sum()
deaths_all
# Out:
# Country/Region
# Australia                  0
# Belgium                    0
# Cambodia                   0
# Canada                     0
# China                   2238
# Egypt                      0
# Finland                    0
# France                     1
# Germany                    0
# India                      0
# Iran                       2
# Italy                      0
# Japan                      1
# Malaysia                   0
# Nepal                      0
# Others                     2
# Philippines                1
# Russia                     0
# Singapore                  0
# South Korea                1
# Spain                      0
# Sri Lanka                  0
# Sweden                     0
# Taiwan                     1
# Thailand                   0
# UK                         0
# US                         0
# United Arab Emirates       0
# Vietnam                    0
# Name: Deaths, dtype: int64

# %%
#interactive map using folium
china_coordinates = (40.18238,116.414)
  
# # create empty map zoomed in on Hubei
# Mymap = folium.Map(location= china_coordinates, zoom_start=12)
 
# # dc=DrawControl(circle={'shapeOptions':{'color':'#0000FF'}})
# # Mymap.add_control(dc)
# Mymap
# Store latitude and longitude in locations
locations = confirmed_df[["Lat", "Long"]]

# Fill NaN values and convert to float
confirmed_cases = main_df["Confirmed"].astype(float)
confirmed_cases.sum()
# Out:
# 781452.0
